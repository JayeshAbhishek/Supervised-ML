# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import statsmodels.formula.api as sm
import scipy, scipy.stats
import math
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Part - A

# %% [markdown]
# ### 1. A. Read all the 3 CSV files as DataFrame and store them into 3 separate variables. [1 Mark]

# %%
df1 = pd.read_csv("Normal.csv")
df2 = pd.read_csv("Type_H.csv")
df3 = pd.read_csv("Type_S.csv")

# %% [markdown]
# ### 1. B. Print Shape and columns of all the 3 DataFrames. [1 Mark]

# %%
print("The shape of df1 is:",df1.shape)
print("The columns for df1 are:",df1.columns)
# Out:
# The shape of df1 is: (100, 7)
# The columns for df1 are: Index(['P_incidence', 'P_tilt', 'L_angle', 'S_slope', 'P_radius', 'S_Degree',
#        'Class'],
#       dtype='object')

# %%
print("The shape of df2 is:",df2.shape)
print("The columns for df2 are:",df2.columns)
# Out:
# The shape of df2 is: (60, 7)
# The columns for df2 are: Index(['P_incidence', 'P_tilt', 'L_angle', 'S_slope', 'P_radius', 'S_Degree',
#        'Class'],
#       dtype='object')

# %%
print("The shape of df3 is:",df3.shape)
print("The columns for df3 are:",df3.columns)
# Out:
# The shape of df3 is: (150, 7)
# The columns for df3 are: Index(['P_incidence', 'P_tilt', 'L_angle', 'S_slope', 'P_radius', 'S_Degree',
#        'Class'],
#       dtype='object')

# %% [markdown]
# ### 1. C. Compare Column names of all the 3 DataFrames and clearly write observations. [1 Mark]

# %% [markdown]
# * All the three dataframes have the same column names and all them are numerical except the "Class" column which is catagorical. The "Class" column has different values in the three dataframes according to the title of the dataset.
# * Looking at the values of all the columns the S_degree of the Type_S dataframe (df3) has higher values compared to the other 2 dataframes. The statistical data of the three dataframes can be seen below.

# %%
df1.describe()
# Out:
#        P_incidence      P_tilt     L_angle     S_slope    P_radius    S_Degree
# count   100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     51.685244   12.821414   43.542605   38.863830  123.890834    2.186572
# std      12.368161    6.778503   12.361388    9.624004    9.014246    6.307483
# min      30.741938   -5.845994   19.071075   17.386972  100.501192  -11.058179
# 25%      42.817849    8.799951   35.000000   32.340487  118.182659   -1.511360
# 50%      50.123115   13.482435   42.638923   37.059694  123.874328    1.152710
# 75%      61.470097   16.785953   51.602346   44.608788  129.040401    4.968807
# max      89.834676   29.894119   90.563461   67.195460  147.894637   31.172767

# %%
df2.describe()
# Out:
#        P_incidence     P_tilt    L_angle    S_slope    P_radius   S_Degree
# count    60.000000  60.000000  60.000000  60.000000   60.000000  60.000000
# mean     47.638407  17.398795  35.463524  30.239612  116.474968   2.480251
# std      10.697131   7.016708   9.767795   7.555388    9.355720   5.531177
# min      26.147921   3.144669  14.000000  13.366931   84.241415 -10.675871
# 25%      41.018099  12.874329  29.038069  25.215275  112.280320  -0.910819
# 50%      46.416169  16.949285  35.164873  30.000659  116.696146   2.542441
# 75%      53.922329  22.002980  42.011563  34.962103  122.042999   6.059666
# max      74.433593  41.557331  62.275275  46.613539  137.540613  15.779697

# %%
df3.describe()
# Out:
#        P_incidence      P_tilt     L_angle     S_slope    P_radius    S_Degree
# count   150.000000  150.000000  150.000000  150.000000  150.000000  150.000000
# mean     71.514224   20.748038   64.110108   50.766186  114.518810   51.896687
# std      15.109337   11.506169   16.397068   12.318813   15.579995   40.108030
# min      37.903910   -6.554948   24.710274   19.290046   70.082575    1.010041
# 25%      60.658136   13.461149   52.000000   43.166815  104.706761   30.393271
# 50%      72.149306   19.309548   62.555200   50.751695  114.842400   42.372509
# 75%      81.075893   29.229680   76.990924   56.675435  123.337307   61.894425
# max     129.834041   49.431864  125.742385  121.429566  163.071041  418.543082

# %% [markdown]
# ### 1. D. Print DataTypes of all the 3 DataFrames. [1 Mark]

# %%
print("The Datatypes of df1 are:",df1.dtypes)
# Out:
# The Datatypes of df1 are: P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object

# %%
print("The Datatypes of df2 are:",df2.dtypes)
# Out:
# The Datatypes of df2 are: P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object

# %%
print("The Datatypes of df3 are:",df3.dtypes)
# Out:
# The Datatypes of df3 are: P_incidence    float64
# P_tilt         float64
# L_angle        float64
# S_slope        float64
# P_radius       float64
# S_Degree       float64
# Class           object
# dtype: object

# %% [markdown]
# ### 1. E. Observe and share variation in ‘Class’ feature of all the 3 DaraFrames. [1 Mark]

# %%
df1["Class"].value_counts()
# Out:
# Normal    73
# Nrmal     27
# Name: Class, dtype: int64

# %%
df2["Class"].value_counts()
# Out:
# Type_H    37
# type_h    23
# Name: Class, dtype: int64

# %%
df3["Class"].value_counts()
# Out:
# Type_S    133
# tp_s       17
# Name: Class, dtype: int64

# %% [markdown]
# 1. The Normal dataframe has 2 variation is "Class" feature which are "Normal and Nrmal"
#
# 2. The Type_H dataframe also has 2 variation is "Class" feature which are "Type_H and type_h"
#
# 2. The Type_S dataframe also has 2 variation is "Class" feature which are "Type_S and tp_s"

# %% [markdown]
# ### 2. A. Unify all the variations in ‘Class’ feature for all the 3 DataFrames. [1 Marks]

# %%
df1.loc[df1["Class"]=="Nrmal","Class"] = "Normal"

df2.loc[df2["Class"]=="type_h","Class"] = "Type_H"

df3.loc[df3["Class"]=="tp_s","Class"] = "Type_S"

# %%
print(df1["Class"].value_counts())
print("")
print(df2["Class"].value_counts())
print("")
print(df3["Class"].value_counts())
# Out:
# Normal    100
# Name: Class, dtype: int64
#
# Type_H    60
# Name: Class, dtype: int64
#
# Type_S    150
# Name: Class, dtype: int64

# %% [markdown]
# ### 2. B. Combine all the 3 DataFrames to form a single DataFrame [1 Marks]

# %%
df = pd.concat([df1,df2,df3])

# %%
df.shape
# Out:
# (310, 7)

# %% [markdown]
# ### 2. C. Print 5 random samples of this DataFrame [1 Marks]

# %%
df.sample(5)
# Out:
#     P_incidence     P_tilt    L_angle    S_slope    P_radius   S_Degree  \
# 6     50.913101   6.677000  30.896522  44.236102  118.151531  -1.057986
# 59    37.140150  16.481240  24.000000  20.658910  125.014361   7.366425
# 63    35.877571   1.112374  43.457257  34.765197  126.923906  -1.632238
# 74    52.204693  17.212673  78.094969  34.992020  136.972517  54.939134
# 49    63.619192  16.934508  49.349262  46.684684  117.089747  -0.357812
#
#      Class
# 6   Normal
# 59  Normal
# 63  Normal
# 74  Type_S
# 49  Normal

# %% [markdown]
# ### 2. D. Print Feature-wise percentage of Null values. [1 Mark]

# %%
for i in df.columns:
    print("Percentage of Null values in",i,":",df[i].isna().sum()/df[i].count()*100,"%")
# Out:
# Percentage of Null values in P_incidence : 0.0 %
# Percentage of Null values in P_tilt : 0.0 %
# Percentage of Null values in L_angle : 0.0 %
# Percentage of Null values in S_slope : 0.0 %
# Percentage of Null values in P_radius : 0.0 %
# Percentage of Null values in S_Degree : 0.0 %
# Percentage of Null values in Class : 0.0 %

# %% [markdown]
# ### 2. E. Check 5-point summary of the new DataFrame. [1 Mark]

# %%
df.describe()
# Out:
#        P_incidence      P_tilt     L_angle     S_slope    P_radius    S_Degree
# count   310.000000  310.000000  310.000000  310.000000  310.000000  310.000000
# mean     60.496653   17.542822   51.930930   42.953831  117.920655   26.296694
# std      17.236520   10.008330   18.554064   13.423102   13.317377   37.559027
# min      26.147921   -6.554948   14.000000   13.366931   70.082575  -11.058179
# 25%      46.430294   10.667069   37.000000   33.347122  110.709196    1.603727
# 50%      58.691038   16.357689   49.562398   42.404912  118.268178   11.767934
# 75%      72.877696   22.120395   63.000000   52.695888  125.467674   41.287352
# max     129.834041   49.431864  125.742385  121.429566  163.071041  418.543082

# %% [markdown]
# ### 3. A. Visualize a heatmap to understand correlation between all features [2 Marks]

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# ### 3. B. Share insights on correlation. [2 Marks]

# %% [markdown]
# #### A. Features having stronger correlation with correlation value:
# P_incidence is having strong correlations with S_Degree (0.64), P_tilt (0.63), L_angle (0.72) and S_slope (0.81). Also P-tilt has a high correlation with S_slope (0.62). L-angle also has high relation with S_slope (0.6) and S-degree (0.53).
#
# #### B. Features having weaker correlation with correlation value.
# P_radius has low correlation with P_incidence (-0.25) and S_slope (-0.34).

# %% [markdown]
# ### 3. C. Visualize a pairplot with 3 classes distinguished by colors and share insights. [2 Marks]

# %%
sns.pairplot(df, hue="Class")
plt.show()

# %% [markdown]
# * Type_S data points have the maximum observations in the dataframe.
# * For S_degree the variation for Normal and Type_H is very low compared to Type_S
# * P_radius has a very low correlation with all the features

# %% [markdown]
# ### 3. D. Visualize a jointplot for ‘P_incidence’ and ‘S_slope’ and share insights. [2 Marks]

# %%
sns.jointplot(df["P_incidence"],df["S_slope"])
plt.show()

# %% [markdown]
# * There is a high correlation between the two features.
# * There are a few outliers other than that majority of the data is concentrated in a region.

# %% [markdown]
# ### 3. E. Visualize a boxplot to check distribution of the features and share insights. [2 Marks]

# %%
for i in df.drop("Class", axis=1).columns:
    sns.boxplot(df["Class"],df[i])
    plt.show()

# %% [markdown]
# #### Insights:
# * We can see a lot of outliers specially for Type_S Class in all features.
# * The median values as well as the Inter quartile range is also higher for Type_S in all almost all features.

# %% [markdown]
# ### 4. A. Split data into X and Y. [1 Marks]

# %%
X = df.drop("Class", axis=1)
y = df["Class"]

# %% [markdown]
# ### 4. B. Split data into train and test with 80:20 proportion. [1 Marks]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.20, random_state=1)

# %% [markdown]
# ### 4. C. Train a Supervised Learning Classification base model using KNN classifier. [2 Marks]

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# %% [markdown]
# ### 4. D. Print all the possible performance metrics for both train and test data. [2 Marks]

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

print("For Test Data")
print("Accuracy Score:",accuracy_score(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred, average='macro'))
print("")
print("For Train Data")
print("Accuracy Score:",knn.score(X_train, y_train))
print("F1 Score:",f1_score(y_train, knn.predict(X_train), average='macro'))
# Out:
# For Test Data
# Accuracy Score: 0.8387096774193549
# F1 Score: 0.8064605959342801
#
# For Train Data
# Accuracy Score: 0.8911290322580645
# F1 Score: 0.860296681307431

# %% [markdown]
# ### 5. A. Experiment with various parameters to improve performance of the base model. [2 Marks]

# %% [markdown]
# #### Scaling the Data

# %%
from scipy.stats import zscore

XScaled  = X.apply(zscore)
X_train, X_test, y_train, y_test = train_test_split(XScaled, y, test_size=0.20, random_state=1)

# %%
knn1 = KNeighborsClassifier()
knn1.fit(X_train, y_train)
y_pred = knn1.predict(X_test)

# %%
print(accuracy_score(y_test, y_pred))
print(f1_score(y_test, y_pred, average='macro'))
# Out:
# 0.7258064516129032
# 0.6923816923816922

# %% [markdown]
# #### Determining the best K

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)

neighbors = range(1,50)

ac_scores = []
for k in neighbors:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)

    scores = accuracy_score(y_test, y_pred)
    ac_scores.append(scores)

# changing to misclassification error
MSE = [1 - x for x in ac_scores]

# determining best k
optimal_k = neighbors[MSE.index(min(MSE))]
print("The optimal number of neighbors is %d" % optimal_k)
# Out:
# The optimal number of neighbors is 1

# %%
plt.plot(neighbors, MSE)
plt.xlabel('Number of Neighbors K')
plt.ylabel('Misclassification Error')
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors = 1)

knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

print(accuracy_score(y_test, y_pred))
print(f1_score(y_test, y_pred, average='macro'))
# Out:
# 0.9032258064516129
# 0.8752136752136752

# %% [markdown]
# ### 5. B. Clearly showcase improvement in performance achieved. [1 Marks]

# %% [markdown]
# #### A. Accuracy: +7.5%
# #### B. F1 Score: +7.1%

# %% [markdown]
# ### 5. C. Clearly state which parameters contributed most to improve model performance. [1 Marks]

# %% [markdown]
# Clearly choosing the optimal value of k contributed most to the improvement of the model.

# %% [markdown]
# ## Part - B

# %% [markdown]
# ### 1. A. Read both the Datasets ‘Data1’ and ‘Data 2’ as DataFrame and store them into two separate variables. [1 Marks]

# %%
df4 = pd.read_csv("Data1.csv")
df5 = pd.read_csv("Data2.csv")

# %% [markdown]
# ### 1. B. Print shape and Column Names and DataTypes of both the Dataframe. [1 Marks]

# %%
print("The shape of df4 is:",df4.shape)
print("")
print("The columns for df4 are:",df4.columns)
print("")
print("The Data Types for the features of df4 are:",df4.dtypes)
# Out:
# The shape of df4 is: (5000, 8)
#
# The columns for df4 are: Index(['ID', 'Age', 'CustomerSince', 'HighestSpend', 'ZipCode', 'HiddenScore',
#        'MonthlyAverageSpend', 'Level'],
#       dtype='object')
#
# The Data Types for the features of df4 are: ID                       int64
# Age                      int64
# CustomerSince            int64
# HighestSpend             int64
# ZipCode                  int64
# HiddenScore              int64
# MonthlyAverageSpend    float64
# Level                    int64
# dtype: object

# %%
print("The shape of df5 is:",df5.shape)
print("")
print("The columns for df5 are:",df5.columns)
print("")
print("The Data Types for the features of df5 are:",df5.dtypes)
# Out:
# The shape of df5 is: (5000, 7)
#
# The columns for df5 are: Index(['ID', 'Mortgage', 'Security', 'FixedDepositAccount', 'InternetBanking',
#        'CreditCard', 'LoanOnCard'],
#       dtype='object')
#
# The Data Types for the features of df5 are: ID                       int64
# Mortgage                 int64
# Security                 int64
# FixedDepositAccount      int64
# InternetBanking          int64
# CreditCard               int64
# LoanOnCard             float64
# dtype: object

# %% [markdown]
# ### 1. C. Merge both the Dataframe on ‘ID’ feature to form a single DataFrame [2 Marks]

# %%
dff = pd.merge(df4,df5, on='ID')
dff.head()
# Out:
#    ID  Age  CustomerSince  HighestSpend  ZipCode  HiddenScore  \
# 0   1   25              1            49    91107            4
# 1   2   45             19            34    90089            3
# 2   3   39             15            11    94720            1
# 3   4   35              9           100    94112            1
# 4   5   35              8            45    91330            4
#
#    MonthlyAverageSpend  Level  Mortgage  Security  FixedDepositAccount  \
# 0                  1.6      1         0         1                    0
# 1                  1.5      1         0         1                    0
# 2                  1.0      1         0         0                    0
# 3                  2.7      2         0         0                    0
# 4                  1.0      2         0         0                    0
#
#    InternetBanking  CreditCard  LoanOnCard
# 0                0           0         NaN
# 1                0           0         NaN
# ...

# %% [markdown]
# ### 1. D. Change Datatype of below features to ‘Object’ [1 Marks]
# ### ‘CreditCard’, ‘InternetBanking’, ‘FixedDepositAccount’, ‘Security’, ‘Level’, ‘HiddenScore’.

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
# ID                     5000 non-null int64
# Age                    5000 non-null int64
# CustomerSince          5000 non-null int64
# HighestSpend           5000 non-null int64
# ZipCode                5000 non-null int64
# HiddenScore            5000 non-null int64
# MonthlyAverageSpend    5000 non-null float64
# Level                  5000 non-null int64
# Mortgage               5000 non-null int64
# Security               5000 non-null int64
# FixedDepositAccount    5000 non-null int64
# InternetBanking        5000 non-null int64
# CreditCard             5000 non-null int64
# LoanOnCard             4980 non-null float64
# dtypes: float64(2), int64(12)
# memory usage: 585.9 KB

# %%
dff[['CreditCard', 'InternetBanking', 'FixedDepositAccount', 'Security', 'Level', 'HiddenScore']] = dff[['CreditCard', 'InternetBanking', 'FixedDepositAccount', 'Security', 'Level', 'HiddenScore']].astype(str)

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
# ID                     5000 non-null int64
# Age                    5000 non-null int64
# CustomerSince          5000 non-null int64
# HighestSpend           5000 non-null int64
# ZipCode                5000 non-null int64
# HiddenScore            5000 non-null object
# MonthlyAverageSpend    5000 non-null float64
# Level                  5000 non-null object
# Mortgage               5000 non-null int64
# Security               5000 non-null object
# FixedDepositAccount    5000 non-null object
# InternetBanking        5000 non-null object
# CreditCard             5000 non-null object
# LoanOnCard             4980 non-null float64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 585.9+ KB

# %% [markdown]
# ### 2. A. Visualize distribution of Target variable ‘LoanOnCard’ and clearly share insights. [2 Marks]

# %%
sns.distplot(dff['LoanOnCard'])
plt.show()

# %%
dff["LoanOnCard"].value_counts()
# Out:
# 0.0    4500
# 1.0     480
# Name: LoanOnCard, dtype: int64

# %% [markdown]
# #### Insights
# * The target column is a binary data column including only 1s and 0s.
# * There is also an imbalance in the data with number of observations of 0 much higher than that of 1.

# %% [markdown]
# ### 2. B. Check the percentage of missing values and impute/drop if required. [1 Marks]

# %%
for i in dff.columns:
    print("Percentage of Null values in",i,":",dff[i].isna().sum()/dff[i].count()*100,"%")
# Out:
# Percentage of Null values in ID : 0.0 %
# Percentage of Null values in Age : 0.0 %
# Percentage of Null values in CustomerSince : 0.0 %
# Percentage of Null values in HighestSpend : 0.0 %
# Percentage of Null values in ZipCode : 0.0 %
# Percentage of Null values in HiddenScore : 0.0 %
# Percentage of Null values in MonthlyAverageSpend : 0.0 %
# Percentage of Null values in Level : 0.0 %
# Percentage of Null values in Mortgage : 0.0 %
# Percentage of Null values in Security : 0.0 %
# Percentage of Null values in FixedDepositAccount : 0.0 %
# Percentage of Null values in InternetBanking : 0.0 %
# Percentage of Null values in CreditCard : 0.0 %
# Percentage of Null values in LoanOnCard : 0.4016064257028112 %

# %%
# As the number of null values are very low, we can drop them

dff.dropna(inplace=True)
dff.isna().sum()
# Out:
# ID                     0
# Age                    0
# CustomerSince          0
# HighestSpend           0
# ZipCode                0
# HiddenScore            0
# MonthlyAverageSpend    0
# Level                  0
# Mortgage               0
# Security               0
# FixedDepositAccount    0
# InternetBanking        0
# CreditCard             0
# LoanOnCard             0
# dtype: int64

# %% [markdown]
# ### 2. C. Check for unexpected values in each categorical variable and impute with best suitable value. [2 Marks]

# %%
dff['HiddenScore'].value_counts()
# Out:
# 1    1466
# 2    1293
# 4    1215
# 3    1006
# Name: HiddenScore, dtype: int64

# %%
dff['Level'].value_counts()
# Out:
# 1    2089
# 3    1496
# 2    1395
# Name: Level, dtype: int64

# %%
dff['Security'].value_counts()
# Out:
# 0    4460
# 1     520
# Name: Security, dtype: int64

# %%
dff['FixedDepositAccount'].value_counts()
# Out:
# 0    4678
# 1     302
# Name: FixedDepositAccount, dtype: int64

# %%
dff['InternetBanking'].value_counts()
# Out:
# 1    2974
# 0    2006
# Name: InternetBanking, dtype: int64

# %%
dff['CreditCard'].value_counts()
# Out:
# 0    3514
# 1    1466
# Name: CreditCard, dtype: int64

# %% [markdown]
# #### There are no abnormalities or unexpected values in Data

# %% [markdown]
# ### 3. A. Split data into X and Y. [1 Marks]

# %%
dff.drop(['ID','ZipCode'], axis=1, inplace = True)
X = dff.drop('LoanOnCard',axis=1)
y = dff['LoanOnCard']

# %% [markdown]
# ### 3. B. Split data into train and test. Keep 25% data reserved for testing. [1 Marks]

# %%
from scipy.stats import zscore
X[['Age', 'CustomerSince', 'HighestSpend', 'MonthlyAverageSpend', 'Mortgage']] = X[['Age', 'CustomerSince', 'HighestSpend', 'MonthlyAverageSpend', 'Mortgage']].apply(zscore)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

# %% [markdown]
# ### 3. C. Train a Supervised Learning Classification base model - Logistic Regression. [2 Marks]

# %%
from sklearn.linear_model import LogisticRegression

logr = LogisticRegression()
logr.fit(X_train, y_train)

y_pred = logr.predict(X_test)

# %% [markdown]
# ### 3. D. Print evaluation metrics for the model and clearly share insights. [1 Marks]

# %%
print("Accuracy:",logr.score(X_test, y_test))
# Out:
# Accuracy: 0.951004016064257

# %%
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
# F1 Score: 0.7239819004524887

# %% [markdown]
# #### The accuracy is high but the F1 score is low, this clearly indicates imbalance in the dataset.

# %% [markdown]
# ### 3. E. Balance the data using the right balancing technique. [2 Marks]

# %%
dff['LoanOnCard'].value_counts()
# Out:
# 0.0    4500
# 1.0     480
# Name: LoanOnCard, dtype: int64

# %%
print("Output of Class 0:", format(dff[dff['LoanOnCard']==0]['LoanOnCard'].count()/dff['LoanOnCard'].count()*100,".2f"),"% and Class 1:", format(dff[dff['LoanOnCard']==1]['LoanOnCard'].count()/dff['LoanOnCard'].count()*100,".2f"),"%")
# Out:
# Output of Class 0: 90.36 % and Class 1: 9.64 %

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(y_train == 1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train == 0)))
  
from imblearn.over_sampling import SMOTE
sm = SMOTE()
X_train_res, y_train_res = sm.fit_sample(X_train, y_train.ravel())
  
print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))
  
print("After OverSampling, counts of label '1': {}".format(sum(y_train_res == 1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res == 0)))
# Out:
# Before OverSampling, counts of label '1': 353
# Before OverSampling, counts of label '0': 3382
#
# After OverSampling, the shape of train_X: (6764, 11)
# After OverSampling, the shape of train_y: (6764,)
#
# After OverSampling, counts of label '1': 3382
# After OverSampling, counts of label '0': 3382

# %% [markdown]
# ### 3. F. Again train the same previous model on balanced data. [1 Marks]

# %%
logr = LogisticRegression()
logr.fit(X_train_res, y_train_res)

y_pred = logr.predict(X_test)

# %% [markdown]
# ### 3. G. Print evaluation metrics and clearly share differences observed. [2 Marks]

# %%
print("Accuracy:",logr.score(X_test, y_test))
# Out:
# Accuracy: 0.8891566265060241

# %%
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
# F1 Score: 0.625

# %% [markdown]
# * The Accuracy seems to have decresed which is very obvious as the imbalance in the feature has been removed.
# * The F1 Score has also decreased, so it seems Logistic regression is not performing well here. we must explore other algorithms.

# %% [markdown]
# ### 4. A. Train a base model each for SVM, KNN. [4 Marks]

# %% [markdown]
# #### SVM

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(X_train_res, y_train_res)

y_pred = svc.predict(X_test)
print("Accuracy:",accuracy_score(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.9654618473895582
# F1 Score: 0.8480565371024735

# %% [markdown]
# #### KNN

# %%
knn = KNeighborsClassifier()

knn.fit(X_train_res, y_train_res)

y_pred1 = knn.predict(X_test)

print("Accuracy:",accuracy_score(y_test, y_pred1))
print("F1 Score:",f1_score(y_test, y_pred, average='macro'))
# Out:
# Accuracy: 0.9566265060240964
# F1 Score: 0.9142865376948707

# %% [markdown]
# ### 4. B. Tune parameters for each of the models wherever required and finalize a model. [3 Marks]

# %% [markdown]
# #### Tuning SVM

# %%
svc_model = SVC(C= .1, kernel='linear', gamma= 1)
svc_model.fit(X_train_res, y_train_res)

y_pred = svc_model .predict(X_test)
print("Accuracy:",accuracy_score(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.885140562248996
# F1 Score: 0.6166219839142091

# %%
svc_model = SVC(kernel='poly')
svc_model.fit(X_train_res, y_train_res)

y_pred = svc_model .predict(X_test)
print("Accuracy:",accuracy_score(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.9630522088353414
# F1 Score: 0.8368794326241134

# %%
svc_model = SVC(kernel='sigmoid')
svc_model.fit(X_train_res, y_train_res)

y_pred = svc_model .predict(X_test)
print("Accuracy:",accuracy_score(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.702008032128514
# F1 Score: 0.33868092691622104

# %% [markdown]
# #### Tuning KNN

# %%
neighbors = range(1,50)

ac_scores = []
for k in neighbors:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_res, y_train_res)
    y_pred = knn.predict(X_test)

    scores = accuracy_score(y_test, y_pred)
    ac_scores.append(scores)

# changing to misclassification error
MSE = [1 - x for x in ac_scores]

# determining best k
optimal_k = neighbors[MSE.index(min(MSE))]
print("The optimal number of neighbors is %d" % optimal_k)
# Out:
# The optimal number of neighbors is 2

# %%
plt.plot(neighbors, MSE)
plt.xlabel('Number of Neighbors K')
plt.ylabel('Misclassification Error')
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors = 4)

knn.fit(X_train_res, y_train_res)

y_pred = knn.predict(X_test)

print("Accuracy:",accuracy_score(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.9710843373493976
# F1 Score: 0.8593749999999999

# %% [markdown]
# ### 4. C. Print evaluation metrics for final model. [1 Marks]

# %%
print("Accuracy:",accuracy_score(y_test, y_pred1))
print("F1 Score:",f1_score(y_test, y_pred1))
# Out:
# Accuracy: 0.9566265060240964
# F1 Score: 0.8071428571428572

# %% [markdown]
# ### 4. D. Share improvement achieved from base model to final model. [2 Marks]

# %% [markdown]
# #### A. Accuracy: +1.5 %
# #### B. F1 Score: +13 %
